# %% [markdown]
# # Final

# %%
import pandas as pd

# %% [markdown]
# ### input data

# %%
data = pd.read_csv('C:\\Users\\User\\Desktop\\final12652\\2019_nCoV_data.csv')
data
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %% [markdown]
# ### Data cleaning

# %%
data.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State     True
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
data['Province/State']=data['Province/State'].fillna('error')
data
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
data.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State    False
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
datai=data

# %% [markdown]
# ### set country as group

# %%
datai = data[data['Country']!='error']

# %%
datai
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
datacovidx = datai.groupby('Country').max().reset_index()
datacovidx
# Out:
#                  Country   Sno                 Date  \
# 0              Australia  1696       2/9/2020 23:20
# 1                Belgium  1704       2/9/2020 23:20
# 2                 Brazil    83  01/23/2020 12:00:00
# 3               Cambodia  1705       2/9/2020 23:20
# 4                 Canada  1706       2/9/2020 23:20
# 5                  China    35  01/22/2020 12:00:00
# 6                  Egypt  1707  02/17/2020 22:00:00
# 7                Finland  1708       2/9/2020 23:20
# 8                 France  1685       2/9/2020 23:20
# 9                Germany  1683       2/9/2020 23:20
# 10             Hong Kong  1677       2/9/2020 23:20
# 11                 India  1693       2/9/2020 23:20
# 12                 Italy  1694       2/9/2020 23:20
# 13           Ivory Coast   264  01/27/2020 20:30:00
# 14                 Japan  1676       2/9/2020 23:20
# 15                 Macau  1686       2/9/2020 23:20
# 16        Mainland China  1709       2/9/2020 23:20
# ...

# %%
import datetime

# %%
data2['Last Update'] = data2['Last Update'].datetime.strptime('%Y-%m-%d,%H:%M:%S')
data2['Last Update'].date.strftime(data2['Last Update'], "%m/%d/%y,%H:%M:%S")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-49481b60d613> in <module>
# ----> 1 data2['Last Update'] = data2['Last Update'].datetime.strptime('%Y-%m-%d,%H:%M:%S')
#       2 data2['Last Update'].date.strftime(data2['Last Update'], "%m/%d/%y,%H:%M:%S")
#
# NameError: name 'data2' is not defined

# %% [markdown]
# ## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ END ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

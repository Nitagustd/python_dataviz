# %% [markdown]
# ## 25/02/2563

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pp
import matplotlib

# %%
income = pd.read_excel('income.xls',header = 3)

# %% [markdown]
# header = คำสั่งบอกหัวตาราง

# %%
bng = income.iloc[4:8,:]

# %%
bng
# Out:
#       ภาค และจังหวัด Unnamed: 1     2541     2543     2545     2547     2549  \
# 4      กรุงเทพมหานคร        NaN  26054.0  26909.0  29589.0  29843.0  36658.0
# 5        สมุทรปราการ        NaN  18100.0  15745.0  19680.0  19946.0  20382.0
# 6            นนทบุรี        NaN  24211.0  24566.0  29119.0  26658.0  31152.0
# 7           ปทุมธานี        NaN  21793.0  19282.0  22838.0  21530.0  25143.0
#
#       2550     2552     2554     2556     2558 Region and province
# 4  39020.0  42380.0  48951.0  49190.8  45571.7             Bangkok
# 5  21302.0  23359.0  23797.9  29575.3  25457.2        Samut Prakan
# 6  32743.0  34626.0  35119.7  30663.6  36884.0          Nonthaburi
# 7  26107.0  26686.0  21615.5  33461.3  41056.9        Pathum Thani

# %% [markdown]
# # BARCHART
# ### สร้างกราฟแท่งเปรียบเทียบรายได้ในปี 2541 ในเขตกรุงเทพและปริมณฑล

# %%
pp.bar([1,2,3,4],bng.iloc[:,2],tick_label = ['bangkok','samothprakan','nontaburi','pratumtani'])
pp.title('income of average montly incomes of province in greater bangkok in 1998')
pp.xlabel('province')
pp.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %% [markdown]
# or

# %%
pp.bar([1,2,3,4],bng.iloc[:,2],tick_label = bng.iloc[:,-1])
pp.title('income of average montly incomes of province in greater bangkok in 1998')
pp.xlabel('province')
pp.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %% [markdown]
# ## Grouped bar chart with labels
# ### compare income in 1998 and 2008

# %%
pp.bar([1+(0.2/2),2+(0.2/2),3+(0.2/2),4+(0.2/2)],bng.iloc[:,2],width = 0.2,tick_label = bng.iloc[:,-1],color = 'c',label ='1998')
pp.bar([1-0.1,2-0.1,3-0.1,4-0.1],bng.iloc[:,-2],width = 0.2,tick_label = bng.iloc[:,-1],color = 'm',label ='2015')
pp.title('income of average montly incomes of province in greater bangkok in 1998 and 2015')
pp.xlabel('province')
pp.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %% [markdown]
# #### move labels

# %%
pp.bar([1+(0.2/2),2+(0.2/2),3+(0.2/2),4+(0.2/2)],bng.iloc[:,2],width = 0.2,tick_label = bng.iloc[:,-1],color = 'c',label ='1998')
pp.bar([1-0.1,2-0.1,3-0.1,4-0.1],bng.iloc[:,-2],width = 0.2,tick_label = bng.iloc[:,-1],color = 'm',label ='2015')
pp.title('Barchart comparing between income of average montly incomes of province in greater bangkok in 1998 and 2015')
pp.xlabel('province')
pp.ylabel('income')
pp.legend(loc = 0)##Loc = location

# %% [markdown]
# Location String	Location Code
#
# 'best'=0,'upper right'=1,'upper left'=2,'lower left'=3,'lower right'=4
#
# 'right'=5,'center left'=6,'center right'=7,'lower center'=8,'upper center'=9,'center'=10

# %% [markdown]
# ## Stacked Bar Graph

# %%
salesdata = pd.DataFrame([{'North':20,'East':50,'West':90,'South':100},
                         {'North':100,'East':40,'West':120,'South':80}])
salesdata
# Out:
#    North  East  West  South
# 0     20    50    90    100
# 1    100    40   120     80

# %%
pp.bar([1,2],salesdata.iloc[:,0],tick_label = ['comp1','comp2'],label ='N')
pp.bar([1,2],salesdata.iloc[:,1],bottom = salesdata.iloc[:,0],label ='E')
pp.bar([1,2],salesdata.iloc[:,2],bottom = salesdata.iloc[:,0]+salesdata.iloc[:,1],label ='W')
pp.bar([1,2],salesdata.iloc[:,3],bottom = salesdata.iloc[:,0]+salesdata.iloc[:,1]+salesdata.iloc[:,2],label ='S')
pp.legend()

# %% [markdown]
# or

# %%
salesdata.loc[:,['North','East','West','South']].plot.bar(stacked=True)

# %% [markdown]
# # ----------------------------------------- CONTINUE ----------------------------------------------------

# %% [markdown]
# # 3/3/63
# ##### blog for visualdata https://jingwen-z.github.io/data-viz-with-matplotlib-series11-histogram/

# %% [markdown]
# ## Histrogram
# ### import datetime สำหรับใส่เวลา

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# random state for reporducibility if use seed(same number)= python give same set of nnumber
np.random.seed(19680801)

# %%
np.random.randn()
# Out:
# 1.0493043103878812

# %% [markdown]
# ปรับให้เป็น std.

# %%
mu,sigma = 100,15
x = mu + sigma * np.random.randn(10000)

# %%
x
# Out:
# array([112.99148762, 108.267019  , 125.92116686, ...,  73.28843349,
#         77.0735325 , 107.25414148])

# %%
#use ; เพื่อย่อ ค่า list x

# %%
plt.hist(x,50,density = True,facecolor = 'b',alpha = 0.5);

# %% [markdown]
# ## Treemap

# %%
import numpy as np
import matplotlib.pyplot as plt
import squarify

# %%
volume = [350, 220, 170, 150, 50]

# %%
squarify.plot(sizes=volume,alpha = 0.5)

# %%
labels = ['Liquid\n volume: 350k', 'Savoury\n volume: 220k',
          'Sugar\n volume: 170k', 'Frozen\n volume: 150k',
          'Non-food\n volume: 50k']
color_list = ['#ffaba3', '#ffe0a3', '#cea3ff',
              '#f9d4d4', '#d35158', '#eea3ff']
plt.rc('font', size=14)
squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=1)

# %%
## \n is new line(ขึ้นบรรทัดใหม่) นำ '#eea3ff' หาในกูเกิ้ลเพื่อเลือกสีที่ชอบ

# %% [markdown]
# ## Radar chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %%
df = [{'client_id':'c1','cheese':2,'beer':2,'chicken':5,'bread':4,'coffee':2},
     {'client_id':'c2','cheese':5,'beer':1,'chicken':3,'bread':3,'coffee':3},
     {'client_id':'c3','cheese':4,'beer':3,'chicken':3,'bread':2,'coffee':5},
     {'client_id':'c4','cheese':3,'beer':5,'chicken':4,'bread':1,'coffee':3}]

# %%
RC =pd.DataFrame(df)
RC
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(RC)[1:]
values = RC.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='black', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],color='red', size=12)
plt.ylim(0, 5)
ax.set_rlabel_position(30)
ax.plot(angles, values, linewidth=1, linestyle='dashdot')
ax.fill(angles, values, 'lightgreen', alpha=0.4)
##This radar chart describes the average products’ preference of 4 clients.

# %%
# เตรียมพื้นที่(ซ้ำกับข้างบน)
categories = list(RC)[1:]
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='black', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],color='red', size=12)
plt.ylim(0, 5)
ax.set_rlabel_position(30)
# part 1
val_c1 = RC.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)
# part 2
val_c2=RC.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)
# part 3
val_c3=RC.loc[2].drop('client_id').values.flatten().tolist()
val_c3 += val_c3[:1]
ax.plot(angles, val_c3, linewidth=1,linestyle='solid', label='Client c3')
ax.fill(angles, val_c3, 'lightgreen', alpha=0.4)
# part 4
val_c4=RC.loc[3].drop('client_id').values.flatten().tolist()
val_c4 += val_c4[:1]
ax.plot(angles, val_c4, linewidth=1,linestyle='solid', label='Client c4')
ax.fill(angles, val_c4, 'lightyellow', alpha=0.4)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %% [markdown]
# ## Word cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

# %%
text = ('Data science is an interdisciplinary field that uses scientificmethods, processes, algorithms and systems toextract knowledge and insightsfrom data in various forms,bothstructured and unstructured, similar to data mining. Datascience is a concept to unify statistics, dataanalysis, machinelearning and their related methods in order to understand andanalyze actualphenomena with data. It employs techniques and theories drawnfrom many fieldswithin the context of mathematics, statistics, informationscience, andcomputer science. Turing award winner Jim Gray imagineddatascience as afourth paradigm of science (empirical,theoretical,computational and nowdata-driven) and asserted that everything about science ischanging because ofthe impact of information technology and the data deluge. In2012, when HarvardBusiness Review called it The Sexiest Job of the 21st Century,the term datascience became a buzzword. It is now often usedinterchangeably with earlierconcepts like business analytics,business intelligence, predictive modeling,and statistics. Even the suggestion that data science is sexywas paraphrasingHans Rosling, featured in a 2011 BBC documentary with thequote, Statistics isnow the sexiest subject around. Nate Silver referred to datascience as a sexedup term for statistics. In many cases, earlier approaches andsolutions are nowsimply rebranded as data science to be more attractive, whichcan cause theterm to become dilute beyond usefulness. While many universityprograms nowoffer a data science degree, there exists no consensus on adefinition orsuitable curriculum contents. To its discredit, however, manydata-science andbig-data projects fail to deliver useful results, often as aresult of poormanagement and utilization of resources')

# %%
# OR use \ to combine next line
text = ('Data science is an interdisciplinary field that uses scientific \
methods, processes, algorithms and systems to extract knowledge and insights\
from data in various forms, both structured and unstructured, similar to data\
mining. Data science is a concept to unify statistics, data analysis, machine\
learning and their related methods in order to understand and analyze actual\
phenomena with data. It employs techniques and theories drawn from many fields\
within the context of mathematics, statistics, information science, and\
computer science. Turing award winner Jim Gray imagined data science as a\
fourth paradigm of science (empirical, theoretical, computational and now\
data-driven) and asserted that everything about science is changing because of\
the impact of information technology and the data deluge. In 2012, when Harvard\
Business Review called it The Sexiest Job of the 21st Century, the term data\
science became a buzzword. It is now often used interchangeably with earlier\
concepts like business analytics, business intelligence, predictive modeling,\
and statistics. Even the suggestion that data science is sexy was paraphrasing\
Hans Rosling, featured in a 2011 BBC documentary with the quote, Statistics is\
now the sexiest subject around. Nate Silver referred to data science as a sexed\
up term for statistics. In many cases, earlier approaches and solutions are now\
simply rebranded as data science to be more attractive, which can cause the\
term to become dilute beyond usefulness. While many university programs now\
offer a data science degree, there exists no consensus on a definition or\
suitable curriculum contents. To its discredit, however, many data-science and\
big-data projects fail to deliver useful results, often as a result of poor\
management and utilization of resources')

# %%
wordcloud = WordCloud(width=1280, height=900, margin=0,colormap='Blues').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# # HOMEWORK

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

# %%
cd = pd.read_csv('message.csv')

# %%
cdnew= cd.iloc[:,4]
cdnew1= str(cdnew)

# %%
cdnew
# Out:
# 0                           Hello
# 1      img : not a parasite image
# 2                 img : Trichuris
# 3                   img : Ascaris
# 4                           อาการ
#                   ...
# 963                           บาย
# 964                       Dee kub
# 965                         ดีคับ
# 966                    สวัสดีครับ
# 967                            Hi
# Name: message, Length: 968, dtype: object

# %%
tt=''
for i in range(len(cd)):
        x = cd.iloc[i,4]
        tt += x

# %%
tt
# Out:
# 'Helloimg : not a parasite imageimg : Trichurisimg : Ascarisอาการชนิดของไข่พยาธิรู้ได้อย่างไรว่าติดพยาธิหวัดดีจ้าimg : Trichurisหวัดดีจ้าimg : hookwormsไข่พยาธิชื่อว่าอะไรไข่พยาธิชื่อว่าอะไรไข่พยาธิกลุ่มใดอาการรู้ได้อย่างไรว่าติดพยาธิimg : Trichurisimg : Trichurisimg : hookwormsลักษณะเด่นของไข่พยาธิimg : Trichurisหวัดดีจ้าาimg : not a parasite imageสวัสดีค่ะHelloจากรูปภาพเป็นไข่พยาธิชนิดใดimg : Taeniaimg : Trichurisอาการimg : OVลักษณะเด่นของไข่พยาธิไข่พยาธิชื่อว่าอะไรวิธีป้องกันHelloimg : not a parasite imageimg : Trichurisอาการimg : EnterobiusHelloimg : Taeniaimg : Ascarisimg : not a parasite imageimg : Taeniaรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิลักษณะทั่วไปตัวเต็มวัยติดต่อสู่คนได้อย่างไรตัวเต็มวัยขนาดเท่าไหร่ไข่พยาธิกลุ่มใดimg : OVรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิimg : Trichurisดีสวัสดีimg : not a parasite imageimg : Taeniaimg : Ascarisรู้ได้อย่างไรว่าติดพยาธิอาการชนิดของไข่พยาธิimg : Trichurisimg : Ascarisimg : Trichurisชนิดของไข่พยาธิลักษณะเด่นของไข่พยาธิไข่พย
# ...

# %%
path = 'C://Users//User//Desktop//T.ton//TH-Sarabun-New//THSarabunNew.ttf'

# %%
regexp = r"[ก-๙a-zA-Z']+"

# %%
wordcloud = WordCloud(font_path=path, relative_scaling = 0.3,min_font_size=1,background_color="white",
                      width=1024,height=768,max_words=2000,  scale=3,font_step=4,collocations=False,
                      regexp=regexp,margin=2,colormap='plasma').generate(tt)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
fig.show()
# Out:
# C:\Users\User\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
wordcloud = WordCloud(
                      font_path=path, 
                      relative_scaling = 0.3,
                      min_font_size=1,
                      background_color="white",
                      width=1024,
                      height=768,
                      max_words=2000, 
                      colormap='plasma', 
                      scale=3,
                      font_step=4,
                    #   contour_width=3, 
                    #   contour_color='steelblue', 
                      collocations=False,
                      regexp=regexp,
                      margin=2
                      ).generate(cdnew1)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

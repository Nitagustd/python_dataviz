# %%
from matplotlib import pyplot as pp
import matplotlib

# %%
import pandas as pd
import numpy as np
iris_PATH = 'C:\\Users\\User\\Downloads\\iris.data'
iris_data = pd.read_csv(iris_PATH ,header = None)

# %% [markdown]
# # 1. Heat map in Visualize array data
#
# numpy = เฉพาะค่าที่เป็นตัวเลข

# %%
data_np = iris_data.iloc[:,:-1].to_numpy()
data_np
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
data_np_onlySeto = iris_data.iloc[:50,:-1].to_numpy()
data_np_onlyversi = iris_data.iloc[50:100,:-1].to_numpy()
data_np_onlyvirgi = iris_data.iloc[100:,:-1].to_numpy()

# %%
matplotlib.rcParams['figure.figsize'] = [10,10]

# %%
pp.subplot(1,3,1)
pp.imshow(data_np_onlySeto,interpolation = 'nearest')
pp.subplot(1,3,2)
pp.imshow(data_np_onlyversi,interpolation = 'nearest')
pp.subplot(1,3,3)
pp.imshow(data_np_onlyvirgi,interpolation = 'nearest')
pp.show()

# %% [markdown]
# # 2. scatter plot

# %%
Seto_np = iris_data.iloc[:50,:-3].to_numpy()

# %%
Seto_np
# Out:
# array([[5.1, 3.5],
#        [4.9, 3. ],
#        [4.7, 3.2],
#        [4.6, 3.1],
#        [5. , 3.6],
#        [5.4, 3.9],
#        [4.6, 3.4],
#        [5. , 3.4],
#        [4.4, 2.9],
#        [4.9, 3.1],
#        [5.4, 3.7],
#        [4.8, 3.4],
#        [4.8, 3. ],
#        [4.3, 3. ],
#        [5.8, 4. ],
#        [5.7, 4.4],
#        [5.4, 3.9],
#        [5.1, 3.5],
#        [5.7, 3.8],
#        [5.1, 3.8],
#        [5.4, 3.4],
#        [5.1, 3.7],
#        [4.6, 3.6],
#        [5.1, 3.3],
#        [4.8, 3.4],
#        [5. , 3. ],
#        [5. , 3.4],
#        [5.2, 3.5],
#        [5.2, 3.4],
#        [4.7, 3.2],
#        [4.8, 3.1],
#        [5.4, 3.4],
#        [5.2, 4.1],
#        [5.5, 4.2],
#        [4.9, 3.1],
#        [5. , 3.2],
#        [5.5, 3.5],
#        [4.9, 3.1],
#        [4.4, 3. ],
#        [5.1, 3.4],
#        [5. , 3.5],
#        [4.5, 2.3],
#        [4.4, 3.2],
#        [5. , 3.5],
#        [5.1, 3.8],
#        [4.8, 3. ],
#        [5.1, 3.8],
# ...

# %%
matplotlib.rcParams['figure.figsize'] = [5,5]
pp.scatter(Seto_np[:,0],Seto_np[:,1])

# %% [markdown]
# ## บอกขนาดมี 2 แบบและใส่โค้ดสี(c,m,y,k,r,g,b)or(hex code)

# %%
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=15, c= 'k')

# %%
Seto_np2 = iris_data.iloc[:50,:-1].to_numpy()
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=10*Seto_np2[:,-2], c= '#990099')

# %% [markdown]
# ![](colors-3.jpg)

# %%
print(f'max = {max(Seto_np2[:,3])},min = {min(Seto_np2[:,3])}')
# Out:
# max = 0.6,min = 0.1

# %% [markdown]
# ### Ues loop add color in parameter c

# %%
color = []
for i in Seto_np2[:,3]:
    if i<0.15:
        color.append('b')
    elif i<0.3:
        color.append('g')
    elif i<0.45:
        color.append('y')        
    else:
        color.append('r')
color
# Out:
# ['g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'b',
#  'g',
#  'y',
#  'y',
#  'y',
#  'y',
#  'y',
#  'g',
#  'y',
#  'g',
#  'r',
#  'g',
#  'g',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'b',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'r',
#  'y',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g']

# %%
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=30, c = color)

# %%
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=30, c = Seto_np[:,1])

# %%
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=30, c = Seto_np[:,1], cmap = pp.get_cmap('twilight_shifted'))

# %% [markdown]
# เฉดสีที่ใช้ได้โดยอัตโนมัติ values are: Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, winter, winter_r

# %%
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=30, c = Seto_np[:,1], cmap = 'YlOrBr')

# %% [markdown]
# ![](colormap.png)

# %% [markdown]
# c = np.array([[R,G,B]] = ค่า RGB เท่าไหร่ในการผสมสี มีค่า 0-1

# %%
matplotlib.rcParams['figure.figsize'] = [20,10]
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=30, c = np.array([[0.6,0.2,0.6]]),marker = 'D')

# %% [markdown]
# เปลี่ยนรูปแบบ จุด โดยใช้ marker

# %%
pp.scatter(Seto_np[:,0],Seto_np[:,1],s=60, c= '#FF0099',marker = '$O$' )

# %% [markdown]
# ### plot over 2 data in 1 scatter plot

# %% [markdown]
# จาก
# >data_np_onlySeto = iris_data.iloc[:50,:-1].to_numpy()
#
# >data_np_onlyversi = iris_data.iloc[50:100,:-1].to_numpy()
#
# >data_np_onlyvirgi = iris_data.iloc[100:,:-1].to_numpy()

# %%
pp.scatter(data_np_onlySeto[:,0],data_np_onlySeto[:,1],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('twilight_shifted'),marker = 'D')
pp.scatter(data_np_onlyversi[:,0],data_np_onlyversi[:,1],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('twilight_shifted'),marker = '*')
pp.scatter(data_np_onlyvirgi[:,0],data_np_onlyvirgi[:,1],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('summer'),marker = 'x')

# %% [markdown]
# ## HomeWork
# supplot 3 class หลายๆแบบ

# %%
matplotlib.rcParams['figure.figsize'] = [5,5]

# %%
pp.scatter(data_np_onlySeto[:,0],data_np_onlySeto[:,1],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('twilight_shifted'),marker = 'D'),
pp.scatter(data_np_onlyversi[:,0],data_np_onlyversi[:,1],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('twilight_shifted'),marker = '*'),
pp.scatter(data_np_onlyvirgi[:,0],data_np_onlyvirgi[:,1],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('summer'),marker = 'x')

# %%
pp.scatter(data_np_onlySeto[:,1],data_np_onlySeto[:,0],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('twilight_shifted'),marker = 'D')
pp.scatter(data_np_onlyversi[:,1],data_np_onlyversi[:,0],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('twilight_shifted'),marker = '*')
pp.scatter(data_np_onlyvirgi[:,1],data_np_onlyvirgi[:,0],s=60,c = Seto_np[:,1], cmap = pp.get_cmap('summer'),marker = 'x')

# %%
onlyseto = iris_data.iloc[:50,:-1].to_numpy()
onlyversi = iris_data.iloc[50:100,:-1].to_numpy()
onlyvirgi = iris_data.iloc[100:,:-1].to_numpy()

# %%
matplotlib.rcParams['figure.figsize'] = [10,10]
pp.subplot(3,4,1)
pp.scatter(onlyseto[:,0],onlyseto[:,1],s=10, c = onlyseto[:,1],marker = 'D')
pp.scatter(onlyversi[:,0],onlyversi[:,1],s=10, c = onlyseto[:,1],marker = '*')
pp.scatter(onlyversi[:,0],onlyversi[:,1],s=10, c = onlyseto[:,1],marker = 'x')
pp.subplot(3,4,2)
pp.scatter(onlyseto[:,0],onlyseto[:,2],s=10, c = onlyseto[:,2],marker = 'D')
pp.scatter(onlyversi[:,0],onlyversi[:,2],s=10, c = onlyseto[:,2],marker = '*')
pp.scatter(onlyversi[:,0],onlyversi[:,2],s=10, c = onlyseto[:,2],marker = 'x')
pp.subplot(3,4,3)
pp.scatter(onlyseto[:,0],onlyseto[:,3],s=10, c = onlyseto[:,3],marker = 'D')
pp.scatter(onlyversi[:,0],onlyversi[:,3],s=10, c = onlyseto[:,3],marker = '*')
pp.scatter(onlyversi[:,0],onlyversi[:,3],s=10, c = onlyseto[:,3],marker = 'x')
pp.subplot(3,4,4)
pp.scatter(onlyseto[:,1],onlyseto[:,0],s=10, c = onlyseto[:,0],marker = 'D')
pp.scatter(onlyversi[:,1],onlyversi[:,0],s=10, c = onlyseto[:,0],marker = '*')
pp.scatter(onlyversi[:,1],onlyversi[:,0],s=10, c = onlyseto[:,0],marker = 'x')
pp.subplot(3,4,5)
pp.scatter(onlyseto[:,1],onlyseto[:,2],s=10, c = onlyseto[:,2],marker = 'D')
pp.scatter(onlyversi[:,1],onlyversi[:,2],s=10, c = onlyseto[:,2],marker = '*')
pp.scatter(onlyversi[:,1],onlyversi[:,2],s=10, c = onlyseto[:,2],marker = 'x')
pp.subplot(3,4,6)
pp.scatter(onlyseto[:,1],onlyseto[:,3],s=10, c = onlyseto[:,3],marker = 'D')
pp.scatter(onlyversi[:,1],onlyversi[:,3],s=10, c = onlyseto[:,3],marker = '*')
pp.scatter(onlyversi[:,1],onlyversi[:,3],s=10, c = onlyseto[:,3],marker = 'x')
pp.subplot(3,4,7)
pp.scatter(onlyseto[:,2],onlyseto[:,0],s=10, c = onlyseto[:,0],marker = 'D')
pp.scatter(onlyversi[:,2],onlyversi[:,0],s=10, c = onlyseto[:,0],marker = '*')
pp.scatter(onlyversi[:,2],onlyversi[:,0],s=10, c = onlyseto[:,0],marker = 'x')
pp.subplot(3,4,8)
pp.scatter(onlyseto[:,2],onlyseto[:,1],s=10, c = onlyseto[:,1],marker = 'D')
pp.scatter(onlyversi[:,2],onlyversi[:,1],s=10, c = onlyseto[:,1],marker = '*')
pp.scatter(onlyversi[:,2],onlyversi[:,1],s=10, c = onlyseto[:,1],marker = 'x')
pp.subplot(3,4,9)
pp.scatter(onlyseto[:,2],onlyseto[:,3],s=10, c = onlyseto[:,2],marker = 'D')
pp.scatter(onlyversi[:,2],onlyversi[:,3],s=10, c = onlyseto[:,2],marker = '*')
pp.scatter(onlyversi[:,2],onlyversi[:,3],s=10, c = onlyseto[:,2],marker = 'x')
pp.subplot(3,4,10)
pp.scatter(onlyseto[:,2],onlyseto[:,3],s=10, c = onlyseto[:,3],marker = 'D')
pp.scatter(onlyversi[:,2],onlyversi[:,3],s=10, c = onlyseto[:,3],marker = '*')
pp.scatter(onlyversi[:,2],onlyversi[:,3],s=10, c = onlyseto[:,3],marker = 'x')
pp.subplot(3,4,11)
pp.scatter(onlyseto[:,3],onlyseto[:,0],s=10, c = onlyseto[:,0],marker = 'D')
pp.scatter(onlyversi[:,3],onlyversi[:,0],s=10, c = onlyseto[:,0],marker = '*')
pp.scatter(onlyversi[:,3],onlyversi[:,0],s=10, c = onlyseto[:,0],marker = 'x')
pp.subplot(3,4,12)
pp.scatter(onlyseto[:,3],onlyseto[:,1],s=10, c = onlyseto[:,0],marker = 'D')
pp.scatter(onlyversi[:,3],onlyversi[:,1],s=10, c = onlyseto[:,0],marker = '*')
pp.scatter(onlyversi[:,3],onlyversi[:,1],s=10, c = onlyseto[:,0],marker = 'x')
